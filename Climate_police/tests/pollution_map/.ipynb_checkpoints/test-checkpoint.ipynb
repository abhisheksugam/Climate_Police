# %%
import pandas as pd

df = pd.read_csv("../../data/pollution_us_2000_2016.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-cd4f6eca0963> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("../../data/pollution_us_2000_2016.csv")
#
# ...

# %%
source = 'NO2'
year = '2008'
option = 'Mean'

# %%
from pollution_map import pollution_map
fig = pollution_map(df, source, year, option)
