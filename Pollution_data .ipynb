# %%
import pandas as pd
import numpy as np

# %%
import zipfile
zf= zipfile.ZipFile ('pollution_us_2000_2016.csv.zip')

# %%
df=pd.read_csv(zf.open("pollution_us_2000_2016.csv"))

# %%
df
# Out:
#          Unnamed: 0  State Code  County Code  Site Num  \
# 0                 0           4           13      3002
# 1                 1           4           13      3002
# 2                 2           4           13      3002
# 3                 3           4           13      3002
# 4                 4           4           13      3002
# 5                 5           4           13      3002
# 6                 6           4           13      3002
# 7                 7           4           13      3002
# 8                 8           4           13      3002
# 9                 9           4           13      3002
# 10               10           4           13      3002
# 11               11           4           13      3002
# 12               12           4           13      3002
# 13               13           4           13      3002
# 14               14           4           13      3002
# 15               15           4           13      3002
# ...
